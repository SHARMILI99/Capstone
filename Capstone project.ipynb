# %%
import pandas as pd
import numpy as np

# %%
from pandas import DataFrame
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
status= pd.read_csv('sales_Status_p3.csv')
status.head()
# Out:
#    Sales_ID sold
# 0         1    Y
# 1         2    Y
# 2         3    Y
# 3         4    Y
# 4         5    Y

# %%
state=pd.read_csv('State_region_mapping_p3.csv')
state.head()
# Out:
#     Region State or Province
# 0  Central          Illinois
# 1  Central           Indiana
# 2  Central              Iowa
# 3  Central            Kansas
# 4  Central          Michigan

# %%
car=pd.read_csv('Car_sales_details_p3.csv')
car.head()
# Out:
#    Sales_ID                          name  year  selling_price  km_driven  \
# 0         1        Maruti Swift Dzire VDI  2014         450000     145500
# 1         2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2         3      Honda City 2017-2020 EXi  2006         158000     140000
# 3         4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4         5        Maruti Swift VXI BSIII  2007         130000     120000
#
#       State or Province           City    fuel seller_type transmission  \
# 0  District of Columbia     Washington  Diesel  Individual       Manual
# 1              New York  New York City  Diesel  Individual       Manual
# 2              Illinois        Chicago  Petrol  Individual       Manual
# 3              Illinois        Chicago  Diesel  Individual       Manual
# 4              New York  New York City  Petrol  Individual       Manual
#
#           owner     mileage   engine   max_power  seats
# ...

# %%
s1= car['name'].unique()
s1
# Out:
# array(['Maruti Swift Dzire VDI', 'Skoda Rapid 1.5 TDI Ambition',
#        'Honda City 2017-2020 EXi', ..., 'Tata Nexon 1.5 Revotorq XT',
#        'Ford Freestyle Titanium Plus Diesel BSIV',
#        'Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV'], dtype=object)

# %%
from collections import Counter
c=Counter(s1)
c
# Out:
# Counter({'Maruti Swift Dzire VDI': 1,
#          'Skoda Rapid 1.5 TDI Ambition': 1,
#          'Honda City 2017-2020 EXi': 1,
#          'Hyundai i20 Sportz Diesel': 1,
#          'Maruti Swift VXI BSIII': 1,
#          'Hyundai Xcent 1.2 VTVT E Plus': 1,
#          'Maruti Wagon R LXI DUO BSIII': 1,
#          'Maruti 800 DX BSII': 1,
#          'Toyota Etios VXD': 1,
#          'Ford Figo Diesel Celebration Edition': 1,
#          'Renault Duster 110PS Diesel RxL': 1,
#          'Maruti Zen LX': 1,
#          'Maruti Swift Dzire VDi': 1,
#          'Maruti Wagon R LXI Minor': 1,
#          'Mahindra KUV 100 mFALCON G80 K8 5str': 1,
#          'Maruti Ertiga SHVS VDI': 1,
#          'Hyundai i20 1.4 CRDi Asta': 1,
#          'Maruti Alto LX': 1,
#          'Hyundai i20 2015-2017 Asta 1.4 CRDi': 1,
#          'Mahindra Verito 1.5 D4 BSIII': 1,
#          'Honda WR-V i-DTEC VX': 1,
#          'Maruti Swift Dzire ZDI': 1,
#          'Maruti SX4 ZDI': 1,
# ...

# %% [markdown]
# ## Question 3

# %%
car['brand']= car['name'].apply(lambda x : x.split(' '))
car['brand']=car['brand'].apply(lambda x: x[0])
car['brand']
# Out:
# 0        Maruti
# 1         Skoda
# 2         Honda
# 3       Hyundai
# 4        Maruti
#          ...
# 7901    Hyundai
# 7902    Hyundai
# 7903     Maruti
# 7904       Tata
# 7905       Tata
# Name: brand, Length: 7906, dtype: object

# %%
from collections import Counter
s1=car['brand']
c=Counter(s1)
c
# Out:
# Counter({'Maruti': 2367,
#          'Skoda': 104,
#          'Honda': 466,
#          'Hyundai': 1360,
#          'Toyota': 452,
#          'Ford': 388,
#          'Renault': 228,
#          'Mahindra': 758,
#          'Tata': 719,
#          'Chevrolet': 230,
#          'Datsun': 65,
#          'Jeep': 31,
#          'Mercedes-Benz': 54,
#          'Mitsubishi': 14,
#          'Audi': 40,
#          'Volkswagen': 185,
#          'BMW': 118,
#          'Nissan': 81,
#          'Lexus': 34,
#          'Jaguar': 71,
#          'Land': 6,
#          'MG': 3,
#          'Volvo': 67,
#          'Daewoo': 3,
#          'Kia': 4,
#          'Fiat': 41,
#          'Force': 6,
#          'Ambassador': 4,
#          'Ashok': 1,
#          'Isuzu': 5,
#          'Opel': 1})

# %%
c.most_common(1)[0][0]
# Out:
# 'Maruti'

# %% [markdown]
# ## Question1

# %%
car.head()
# Out:
#    Sales_ID                          name  year  selling_price  km_driven  \
# 0         1        Maruti Swift Dzire VDI  2014         450000     145500
# 1         2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2         3      Honda City 2017-2020 EXi  2006         158000     140000
# 3         4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4         5        Maruti Swift VXI BSIII  2007         130000     120000
#
#       State or Province           City    fuel seller_type transmission  \
# 0  District of Columbia     Washington  Diesel  Individual       Manual
# 1              New York  New York City  Diesel  Individual       Manual
# 2              Illinois        Chicago  Petrol  Individual       Manual
# 3              Illinois        Chicago  Diesel  Individual       Manual
# 4              New York  New York City  Petrol  Individual       Manual
#
#           owner     mileage   engine   max_power  seats    brand
# ...

# %%
car['year'].unique()
# Out:
# array([2014, 2006, 2010, 2007, 2017, 2001, 2011, 2013, 2005, 2009, 2016,
#        2012, 2002, 2015, 2018, 2019, 2008, 2020, 1999, 2000, 2003, 2004,
#        1994, 1998, 1997, 1995, 1996], dtype=int64)

# %%
car.corr()
# Out:
#                Sales_ID      year  selling_price  km_driven     seats
# Sales_ID       1.000000 -0.001304      -0.012125   0.009556 -0.014154
# year          -0.001304  1.000000       0.412302  -0.428548 -0.007923
# selling_price -0.012125  0.412302       1.000000  -0.222158  0.041617
# km_driven      0.009556 -0.428548      -0.222158   1.000000  0.227259
# seats         -0.014154 -0.007923       0.041617   0.227259  1.000000

# %%
price={'Sales_id':-0.012125,'year':0.412302,'km_driven':-0.222158,'seats':0.041617}

# %%
sns.pairplot(data=car,x_vars=['Sales_ID','year','km_driven','seats'],y_vars=['selling_price'])

# %%
#here we can see a positive relationship between price and year
#we can infer that: older cars tend to have less price
#there is a negative relationship between price and km_driven
#we can infer that: the price for less driven vehicles is low

# %%
sns.FacetGrid(col='owner',data=car, aspect=1.6,height=4).map(plt.hist,'selling_price').fig.subplots_adjust(wspace=1,hspace=1)
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
plt.scatter(car['owner'],car['selling_price'])
plt.ylabel('Price')
plt.xlabel('Owner')
# Out:
# Text(0.5, 0, 'Owner')

# %%
#s1= car['selling_price'].corr(car, min_periods=1)

#sns.heatmap(car['selling_price'].corr(),annot=True, cmap='summer')
